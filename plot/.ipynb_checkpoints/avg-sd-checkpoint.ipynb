# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define the list of file names for Amber and OpenMM
amber_filenames = [
    '../AMBER-benchmark/benchmark_6n4o_pmemd/sylvaner/GTX_1080_Ti_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/case/TITAN_V_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/case/RTX_5000_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/cerebro/RTX_6000_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/cerebro/GP100_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/cerebro/RTX_2080_Ti_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/rioja/RTX_3090_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/rioja/RTX_5000_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/rioja/RTX_A4500_results_amber.dat'
]

openmm_filenames = [
    '../OPENMM-benchmark/benchmark_6n4o_openmm/sylvaner/GTX_1080_Ti_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/case/TITAN_V_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/case/Quadro_RTX_5000_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/cerebro/RTX_6000_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/cerebro/GP100_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/cerebro/RTX_2080_Ti_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/rioja/RTX_3090_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/rioja/RTX_5000_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/rioja/RTX_A4500_results_openmm.dat'
]

amber_device = [
    'GTX_1080_Ti', 'TITAN_V', 'RTX_5000', 'RTX_6000', 'GP100',
    'RTX_2080_Ti', 'RTX_3090', 'RTX_5000', 'RTX_A4500'
]

openmm_device = [
    'GTX_1080_Ti', 'TITAN_V', 'Quadro_RTX_5000', 'RTX_6000', 'GP100',
    'RTX_2080_Ti', 'RTX_3090', 'RTX_5000', 'RTX_A4500'
]

# Initialize lists to hold the averages and standard deviations for Amber and OpenMM
amber_averages = []
amber_standard_deviations = []
openmm_averages = []
openmm_standard_deviations = []

# Loop through each file, calculate the average and standard deviation of the second column for Amber
for file in amber_filenames:
    # Check if file exists
    if not os.path.isfile(file):
        print(f"File {file} not found.")
        continue

    # Read the data from the file
    data = pd.read_csv(file, sep='\s+', header=None)
    second_column = data.iloc[:, 0]

    # Calculate average and standard deviation and append to Amber lists
    amber_averages.append(second_column.mean())
    amber_standard_deviations.append(second_column.std())

# Loop through each file, calculate the average and standard deviation of the second column for OpenMM
for file in openmm_filenames:
    # Check if file exists
    if not os.path.isfile(file):
        print(f"File {file} not found.")
        continue

    # Read the data from the file
    data = pd.read_csv(file, sep='\s+', header=None)
    second_column = data.iloc[:, 0]

    # Calculate average and standard deviation and append to OpenMM lists
    openmm_averages.append(second_column.mean())
    openmm_standard_deviations.append(second_column.std())

# Create a single figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Create bar plots with error bars for Amber and OpenMM
x_positions = np.arange(len(amber_device))
ax1.bar(x_positions, amber_averages, yerr=amber_standard_deviations, align='center', alpha=0.7, ecolor='black', capsize=10, color="blue")
ax2.bar(x_positions, openmm_averages, yerr=openmm_standard_deviations, align='center', alpha=0.7, ecolor='black', capsize=10, color="red")

# Add labels and titles
ax1.set_ylabel('ns/day')
ax2.set_ylabel('ns/day')
ax1.set_title('6N4O_AMBER_cuda_results')
ax2.set_title('6N4O_OPENMM_cuda_results')
ax1.set_xticks(x_positions)
ax2.set_xticks(x_positions)
ax1.set_xticklabels(amber_device, rotation="vertical")
ax2.set_xticklabels(openmm_device, rotation="vertical")
ax1.set_yticks(np.arange(0, 51, 10))
ax2.set_yticks(np.arange(0, 51, 10))
ax1.set_ylim(top=50, bottom=0)
ax2.set_ylim(top=50, bottom=0)

# Adjust subplot spacing
plt.tight_layout()

# Save the combined plot
plt.savefig('combined_benchmarks.jpg', dpi=450, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define the list of file names for Amber and OpenMM
amber_filenames = [
    '../AMBER-benchmark/benchmark_6n4o_pmemd/sylvaner/GTX_1080_Ti_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/case/TITAN_V_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/case/RTX_5000_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/cerebro/RTX_6000_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/cerebro/GP100_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/cerebro/RTX_2080_Ti_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/rioja/RTX_3090_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/rioja/RTX_5000_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/rioja/RTX_A4500_results_amber.dat'
]

openmm_filenames = [
    '../OPENMM-benchmark/benchmark_6n4o_openmm/sylvaner/GTX_1080_Ti_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/case/TITAN_V_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/case/Quadro_RTX_5000_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/cerebro/RTX_6000_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/cerebro/GP100_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/cerebro/RTX_2080_Ti_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/rioja/RTX_3090_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/rioja/RTX_5000_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/rioja/RTX_A4500_results_openmm.dat'
]

namd_filenames = [
    '../NAMD-benchmark/benchmark_6n4o_namd/sylvaner/GTX_1080_Ti_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/case/TITAN_V_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/case/Quadro_RTX_5000_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/cerebro/RTX_6000_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/cerebro/GP100_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/cerebro/RTX_2080_Ti_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/rioja/RTX_3090_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/rioja/RTX_5000_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/rioja/RTX_A4500_results_namd.dat'
]


# gromacs_filenames = [
#     '../GROMACS-benchmark/benchmark_6n4o_gromacs/sylvaner/GTX_1080_Ti_results_openmm.dat',
#     '../GROMACS-benchmark/benchmark_6n4o_gromacs/case/TITAN_V_results_openmm.dat',
#     '../GROMACS-benchmark/benchmark_6n4o_gromacs/case/Quadro_RTX_5000_results_openmm.dat',
#     '../GROMACS-benchmark/benchmark_6n4o_gromacs/cerebro/RTX_6000_results_openmm.dat',
#     '../GROMACS-benchmark/benchmark_6n4o_gromacs/cerebro/GP100_results_openmm.dat',
#     '../GROMACS-benchmark/benchmark_6n4o_gromacs/cerebro/RTX_2080_Ti_results_openmm.dat',
#     '../GROMACS-benchmark/benchmark_6n4o_gromacs/rioja/RTX_3090_results_openmm.dat',
#     '../GROMACS-benchmark/benchmark_6n4o_gromacs/rioja/RTX_5000_results_openmm.dat',
#     '../GROMACS-benchmark/benchmark_6n4o_gromacs/rioja/RTX_A4500_results_openmm.dat'
# ]

amber_device = [
    'GTX_1080_Ti', 'TITAN_V', 'RTX_5000', 'RTX_6000', 'GP100',
    'RTX_2080_Ti', 'RTX_3090', 'RTX_5000', 'RTX_A4500'
]

openmm_device = [
    'GTX_1080_Ti', 'TITAN_V', 'Quadro_RTX_5000', 'RTX_6000', 'GP100',
    'RTX_2080_Ti', 'RTX_3090', 'RTX_5000', 'RTX_A4500'
]

namd_device = [
    'GTX_1080_Ti', 'TITAN_V', 'Quadro_RTX_5000', 'RTX_6000', 'GP100',
    'RTX_2080_Ti', 'RTX_3090', 'RTX_5000', 'RTX_A4500'
]

# Initialize lists to hold the averages and standard deviations for Amber and OpenMM
amber_averages = []
amber_standard_deviations = []
openmm_averages = []
openmm_standard_deviations = []
namd_averages = []
namd_standard_deviations = []


# Loop through each file, calculate the average and standard deviation of the second column for Amber
for file in amber_filenames:
    # Check if file exists
    if not os.path.isfile(file):
        print(f"File {file} not found.")
        continue

    # Read the data from the file
    data = pd.read_csv(file, sep='\s+', header=None)
    second_column = data.iloc[:, 0]

    # Calculate average and standard deviation and append to Amber lists
    amber_averages.append(second_column.mean())
    amber_standard_deviations.append(second_column.std())

# Loop through each file, calculate the average and standard deviation of the second column for OpenMM
for file in openmm_filenames:
    # Check if file exists
    if not os.path.isfile(file):
        print(f"File {file} not found.")
        continue

    # Read the data from the file
    data = pd.read_csv(file, sep='\s+', header=None)
    second_column = data.iloc[:, 0]

    # Calculate average and standard deviation and append to OpenMM lists
    openmm_averages.append(second_column.mean())
    openmm_standard_deviations.append(second_column.std())
    
# Loop through each file, calculate the average and standard deviation of the second column for NAMD
for file in namd_filenames:
    # Check if file exists
    if not os.path.isfile(file):
        print(f"File {file} not found.")
        continue

    # Read the data from the file
    data = pd.read_csv(file, sep='\s+', header=None)
    second_column = data.iloc[:, 0]

    # Calculate average and standard deviation and append to OpenMM lists
    namd_averages.append(second_column.mean())
    namd_standard_deviations.append(second_column.std())


# Create a single figure and plot both Amber and OpenMM data on the same plot
x_positions = np.arange(len(amber_device))
width = 0.25

fig, ax = plt.subplots(figsize=(12, 6))
amber_bars = ax.bar(x_positions - width, amber_averages, width, label='AMBER', yerr=amber_standard_deviations, alpha=0.7, ecolor='black', capsize=10, color="blue")
openmm_bars = ax.bar(x_positions, openmm_averages, width, label='OPENMM', yerr=openmm_standard_deviations, alpha=0.7, ecolor='black', capsize=10, color="red")
namd_bars = ax.bar(x_positions + width, namd_averages, width, label='NAMD', yerr=namd_standard_deviations, alpha=0.7, ecolor='black', capsize=10, color="green")

# fig, ax = plt.subplots(figsize=(12, 6))
# amber_bars = ax.bar(x_positions - width/2, amber_averages, width, label='AMBER', yerr=amber_standard_deviations, alpha=0.7, ecolor='black', capsize=10, color="blue")
# openmm_bars = ax.bar(x_positions, openmm_averages, width, label='OPENMM', yerr=openmm_standard_deviations, alpha=0.7, ecolor='black', capsize=10, color="red")
# namd_bars = ax.bar(x_positions + width/2, namd_averages, width, label='NAMD', yerr=namd_standard_deviations, alpha=0.7, ecolor='black', capsize=10, color="green")

# Add labels and titles
ax.set_ylabel('ns/day')
ax.set_title('6N4O Benchmark Results')
ax.set_xticks(x_positions)
ax.set_xticklabels(amber_device, rotation="vertical")
ax.set_yticks(np.arange(0, 51, 10))
ax.set_ylim(top=50, bottom=0)
ax.legend()

# Save the combined plot
plt.tight_layout()
plt.savefig('combined_benchmarks.jpg', dpi=450, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define the list of file names for Amber and OpenMM
amber_filenames = [
    '../AMBER-benchmark/benchmark_6n4o_pmemd/sylvaner/GTX_1080_Ti_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/case/TITAN_V_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/case/RTX_5000_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/cerebro/RTX_6000_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/cerebro/GP100_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/cerebro/RTX_2080_Ti_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/rioja/RTX_3090_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/rioja/RTX_5000_results_amber.dat',
    '../AMBER-benchmark/benchmark_6n4o_pmemd/rioja/RTX_A4500_results_amber.dat'
]

openmm_filenames = [
    '../OPENMM-benchmark/benchmark_6n4o_openmm/sylvaner/GTX_1080_Ti_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/case/TITAN_V_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/case/Quadro_RTX_5000_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/cerebro/RTX_6000_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/cerebro/GP100_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/cerebro/RTX_2080_Ti_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/rioja/RTX_3090_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/rioja/RTX_5000_results_openmm.dat',
    '../OPENMM-benchmark/benchmark_6n4o_openmm/rioja/RTX_A4500_results_openmm.dat'
]

namd_filenames = [
    '../NAMD-benchmark/benchmark_6n4o_namd/sylvaner/GTX_1080_Ti_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/case/TITAN_V_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/case/Quadro_RTX_5000_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/cerebro/RTX_6000_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/cerebro/GP100_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/cerebro/RTX_2080_Ti_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/rioja/RTX_3090_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/rioja/RTX_5000_results_namd.dat',
    '../NAMD-benchmark/benchmark_6n4o_namd/rioja/RTX_A4500_results_namd.dat'
]

device = [
    'GTX_1080_Ti', 'TITAN_V', 'Quadro_RTX_5000', 'RTX_6000', 'GP100',
    'RTX_2080_Ti', 'RTX_3090', 'RTX_5000', 'RTX_A4500'
]

# Initialize lists to hold the averages and standard deviations for Amber, OpenMM, and NAMD
amber_averages = []
amber_standard_deviations = []
openmm_averages = []
openmm_standard_deviations = []
namd_averages = []
namd_standard_deviations = []

# Loop through each file, calculate the average and standard deviation of the second column for Amber
for file in amber_filenames:
    # Check if file exists
    if not os.path.isfile(file):
        print(f"File {file} not found.")
        continue

    # Read the data from the file
    data = pd.read_csv(file, sep='\s+', header=None)
    second_column = data.iloc[:, 0]

    # Calculate average and standard deviation and append to Amber lists
    amber_averages.append(second_column.mean())
    amber_standard_deviations.append(second_column.std())

# Loop through each file, calculate the average and standard deviation of the second column for OpenMM
for file in openmm_filenames:
    # Check if file exists
    if not os.path.isfile(file):
        print(f"File {file} not found.")
        continue

    # Read the data from the file
    data = pd.read_csv(file, sep='\s+', header=None)
    second_column = data.iloc[:, 0]

    # Calculate average and standard deviation and append to OpenMM lists
    openmm_averages.append(second_column.mean())
    openmm_standard_deviations.append(second_column.std())

# Loop through each file, calculate the average and standard deviation of the second column for NAMD
for file in namd_filenames:
    # Check if file exists
    if not os.path.isfile(file):
        print(f"File {file} not found.")
        continue

    # Read the data from the file
    data = pd.read_csv(file, sep='\s+', header=None)
    second_column = data.iloc[:, 0]

    # Calculate average and standard deviation and append to NAMD lists
    namd_averages.append(second_column.mean())
    namd_standard_deviations.append(second_column.std())

# Create a single figure and plot both Amber and OpenMM data on the same plot
x_positions = np.arange(len(device))
width = 0.25

fig, ax = plt.subplots(figsize=(12, 6))
amber_bars = ax.bar(x_positions, amber_averages, width, label='AMBER', yerr=amber_standard_deviations, alpha=0.7, ecolor='black', capsize=10, color="blue")
openmm_bars = ax.bar(x_positions + width, openmm_averages, width, label='OPENMM', yerr=openmm_standard_deviations, alpha=0.7, ecolor='black', capsize=10, color="red")
namd_bars = ax.bar(x_positions + 2 * width, namd_averages, width, label='NAMD', yerr=namd_standard_deviations, alpha=0.7, ecolor='black', capsize=10, color="green")

# Add labels and titles
ax.set_ylabel('ns/day')
ax.set_title('6N4O Benchmark Results')
ax.set_xticks(x_positions + width)
ax.set_xticklabels(device, rotation="vertical")
ax.set_yticks(np.arange(0, 51, 10))
ax.set_ylim(top=50, bottom=0)
ax.legend()

# Save the combined plot
plt.tight_layout()
plt.savefig('combined_benchmarks.jpg', dpi=450, bbox_inches='tight')

# Display the plot
plt.show()
